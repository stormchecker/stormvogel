# %%
import networkx as nx

import stormvogel.examples as examples
from stormvogel.graph import ModelGraph
from stormvogel.visualization import JSVisualization, MplVisualization
from stormvogel.layout import DEFAULT
from stormvogel.show import show


mdp = examples.create_lion_mdp()
G = ModelGraph.from_model(mdp)
pos = nx.bfs_layout(G, start=mdp.initial_state)

layout = DEFAULT().set_nx_pos(pos)
vis = show(mdp, layout=layout, show_editor=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 15
#      12 pos = nx.bfs_layout(G, start=mdp.initial_state)
#      14 layout = DEFAULT().set_nx_pos(pos)
# ---> 15 vis = show(mdp, layout=layout, show_editor=True)
#
# File ~/git/stormpy/stormvogel/.venv/lib/python3.12/site-packages/stormvogel/show.py:76, in show(model, result, engine, pos_function, pos_function_scaling, scheduler, layout, show_editor, debug_output, use_iframe, do_init_server, max_states, max_physics_states)
#      73         pass
#      75 if engine == "js":
# ---> 76     vis = JSVisualization(
#      77         model=model,
#      78         result=result,
#      79         scheduler=scheduler,
#      80         layout=layout,
#      81         debug_output=debug_output or widgets.Output(),
#      82         do_init_server=do_init_server,
#      83         use_iframe=use_iframe,
#      84         max_states=max_states,
#      85         max_physics_states=max_physics_states,
#      86     )
#      87     if show_editor:
#      88         import stormvogel.layout_editor
#
# File ~/git/stormpy/stormvogel/.venv/lib/python3.12/site-packages/stormvogel/visualization.py:382, in JSVisualization.__init__(self, model, name, result, scheduler, layout, output, debug_output, use_iframe, do_init_server, max_states, max_physics_states)
#     379 import ipywidgets as widgets  # local, heavy
#     380 import os
# --> 382 super().__init__(model, layout, result, scheduler)
#     384 self.initial_state = model.initial_state
#     386 if output is None:
#
# File ~/git/stormpy/stormvogel/.venv/lib/python3.12/site-packages/stormvogel/visualization.py:75, in VisualizationBase.__init__(self, model, layout, result, scheduler)
#      73 else:  # Otherwise, disable it
#      74     self.layout.remove_active_group("scheduled_actions")
# ---> 75 self.recreate()
#
# File ~/git/stormpy/stormvogel/.venv/lib/python3.12/site-packages/stormvogel/visualization.py:120, in VisualizationBase.recreate(self)
#     117 """Recreate the ModelGraph and set the edit groups."""
#     118 from .graph import ModelGraph
# --> 120 self.G = ModelGraph.from_model(
#     121     self.model,
#     122     state_properties=self._create_state_properties,
#     123     action_properties=self._create_action_properties,
#     124     transition_properties=self._create_transition_properties,
#     125 )
#     126 underscored_labels = set(map(self._und, self.model.get_labels()))
#     127 possible_groups = underscored_labels.union(
#     128     {"states", "actions", "scheduled_actions"}
#     129 )
#
# File ~/git/stormpy/stormvogel/.venv/lib/python3.12/site-packages/stormvogel/graph.py:139, in ModelGraph.from_model(cls, model, state_properties, action_properties, transition_properties)
#     137     props = dict()
#     138     if state_properties is not None:
# --> 139         props = state_properties(state)
#     140     G.add_state(state, **props)
#     142 for state, choice in model.choices.items():
#
# File ~/git/stormpy/stormvogel/.venv/lib/python3.12/site-packages/stormvogel/visualization.py:261, in VisualizationBase._create_state_properties(self, state)
#     259 res = self._format_result(state)
#     260 observations = self._format_observations(state)
# --> 261 rewards = self._format_rewards(state, stormvogel.model.EmptyAction)
#     262 group = self._group_state(state, "states")
#     263 id_label_part = (
#     264     f"{state}\n" if self.layout.layout["state_properties"]["show_ids"] else ""
#     265 )
#
# File ~/git/stormpy/stormvogel/.venv/lib/python3.12/site-packages/stormvogel/visualization.py:226, in VisualizationBase._format_rewards(self, s, a)
#     224     else:
#     225         reward = reward_model.get_state_reward(s)
# --> 226     if reward is not None and not (
#     227         not self.layout.layout["state_properties"]["show_zero_rewards"]
#     228         and reward == 0
#     229     ):
#     230         res += f"\t{reward_model.name}: {self._format_number(reward)}"
#     231 if res == EMPTY_RES:
#
# UnboundLocalError: cannot access local variable 'reward' where it is not associated with a value

# %%
layout = DEFAULT().set_nx_pos(pos)
layout.set_value(["groups", "states", "color", "background"], "black")
MplVisualization(mdp, layout=layout).show()
